# %%
# Import Libaries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configurations of the plots we will create

# Read in the data

df = pd.read_csv(r'C:\Users\Mat\Downloads/movies.csv')

# %%
# Let's look at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#      released releasedcountry  score        votes         director  \
# 0  1980-06-13   United States   8.40   927,000.00  Stanley Kubrick
# 1  1980-07-02   United States   5.80    65,000.00   Randal Kleiser
# 2  1980-06-20   United States   8.70 1,200,000.00   Irvin Kershner
# 3  1980-07-02   United States   7.70   221,000.00     Jim Abrahams
# 4  1980-07-25   United States   7.30   108,000.00     Harold Ramis
#
#                     writer            star         country        budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom 19,000,000.00
# 1  Henry De Vere Stacpoole  Brooke Shields   United States  4,500,000.00
# 2           Leigh Brackett     Mark Hamill   United States 18,000,000.00
# 3             Jim Abrahams     Robert Hays   United States  3,500,000.00
# 4       Brian Doyle-Murray     Chevy Chase   United States  6,000,000.00
#
#            gross             company  runtime
# 0  46,998,772.00        Warner Bros.   146.00
# 1  58,853,106.00   Columbia Pictures   104.00
# 2 538,375,067.00           Lucasfilm   124.00
# 3  83,453,539.00  Paramount Pictures    88.00
# 4  39,846,344.00      Orion Pictures    98.00

# %%
# Missing Data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# releasedcountry - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Datat types for columns

df.dtypes
# Out:
# name                object
# rating              object
# genre               object
# year                 int64
# released            object
# releasedcountry     object
# score              float64
# votes              float64
# director            object
# writer              object
# star                object
# country             object
# budget             float64
# gross              float64
# company             object
# runtime            float64
# dtype: object

# %%
#Changing data type (note that "int64" will not allow NA values, you must use "Int64" to change data to int AND allow na values)

df[ 'budget' ] = df[ 'budget' ].astype('Int64')
df[ 'gross' ] = df[ 'gross' ].astype('Int64')

#or you can fill in NA with 0 which works too
df["budget"] = df["budget"].fillna(0)
df["gross"] = df["gross"].fillna(0)

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#      released releasedcountry  score        votes         director  \
# 0  1980-06-13   United States   8.40   927,000.00  Stanley Kubrick
# 1  1980-07-02   United States   5.80    65,000.00   Randal Kleiser
# 2  1980-06-20   United States   8.70 1,200,000.00   Irvin Kershner
# 3  1980-07-02   United States   7.70   221,000.00     Jim Abrahams
# 4  1980-07-25   United States   7.30   108,000.00     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime
# 0   46998772        Warner Bros.   146.00
# 1   58853106   Columbia Pictures   104.00
# 2  538375067           Lucasfilm   124.00
# 3   83453539  Paramount Pictures    88.00
# 4   39846344      Orion Pictures    98.00

# %%
# Create correct year Column
df['yearcorrect'] = df['released'].astype(str).str[:4]
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#      released releasedcountry  score        votes         director  \
# 0  1980-06-13   United States   8.40   927,000.00  Stanley Kubrick
# 1  1980-07-02   United States   5.80    65,000.00   Randal Kleiser
# 2  1980-06-20   United States   8.70 1,200,000.00   Irvin Kershner
# 3  1980-07-02   United States   7.70   221,000.00     Jim Abrahams
# 4  1980-07-25   United States   7.30   108,000.00     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime yearcorrect
# 0   46998772        Warner Bros.   146.00        1980
# 1   58853106   Columbia Pictures   104.00        1980
# 2  538375067           Lucasfilm   124.00        1980
# 3   83453539  Paramount Pictures    88.00        1980
# 4   39846344      Orion Pictures    98.00        1980

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
pd.set_option('display.max_rows', None)

# %%
# Remove duplicates
#df["company"].drop_duplicates().sort_values(ascending=False)

# to acctually drop Duplicates -> df.drop_duplicates()

# %%
# Budget vs Gross Scatter Plot


plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for Film')

plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#         released releasedcountry  score        votes       director  \
# 5445  2009-12-18   United States   7.80 1,100,000.00  James Cameron
# 7445  2019-04-26   United States   8.40   903,000.00  Anthony Russo
# 3045  1997-12-19   United States   7.80 1,100,000.00  James Cameron
# 6663  2015-12-18   United States   7.80   876,000.00    J.J. Abrams
# 7244  2018-04-27   United States   8.40   897,000.00  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime yearcorrect
# 5445  2847246203  Twentieth Century Fox   162.00        2009
# 7445  2797501328         Marvel Studios   181.00        2019
# 3045  2201647264  Twentieth Century Fox   194.00        1997
# 6663  2069521700              Lucasfilm   138.00        2015
# 7244  2048359754         Marvel Studios   149.00        2018

# %%
# Plot budget vs gross using seaborn

#sns.regplot(x='budget' , y='gross', data=df, scatter_kws={"color": "blue"}, line_kws={"color":"blue"})

# %%
# Looking at correlation

# %%
pd.set_option("display.precision", 8)
df.corr(method='pearson') #pearson, kendall, spearman
# Out:
# C:\Users\Mat\AppData\Local\Temp\ipykernel_12968\3108497647.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson') #pearson, kendall, spearman
#          year  score  votes  budget  gross  runtime
# year     1.00   0.10   0.22    0.31   0.26     0.12
# score    0.10   1.00   0.41    0.06   0.19     0.40
# votes    0.22   0.41   1.00    0.49   0.63     0.31
# budget   0.31   0.06   0.49    1.00   0.75     0.27
# gross    0.26   0.19   0.63    0.75   1.00     0.25
# runtime  0.12   0.40   0.31    0.27   0.25     1.00

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()
# Out:
# C:\Users\Mat\AppData\Local\Temp\ipykernel_12968\2708932002.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr(method='pearson')

# %%
# Looking at Company

df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#         released releasedcountry  score        votes       director  \
# 5445  2009-12-18   United States   7.80 1,100,000.00  James Cameron
# 7445  2019-04-26   United States   8.40   903,000.00  Anthony Russo
# 3045  1997-12-19   United States   7.80 1,100,000.00  James Cameron
# 6663  2015-12-18   United States   7.80   876,000.00    J.J. Abrams
# 7244  2018-04-27   United States   8.40   897,000.00  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime yearcorrect
# 5445  2847246203  Twentieth Century Fox   162.00        2009
# 7445  2797501328         Marvel Studios   181.00        2019
# 3045  2201647264  Twentieth Century Fox   194.00        1997
# 6663  2069521700              Lucasfilm   138.00        2015
# 7244  2048359754         Marvel Studios   149.00        2018

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized.head()
# Out:
#       name  rating  genre  year  released  releasedcountry  score  \
# 5445   533       5      0  2009      2107               56   7.80
# 7445   535       5      0  2019      2865               56   8.40
# 3045  6896       5      6  1997      1224               56   7.80
# 6663  5144       5      0  2015      2609               56   7.80
# 7244   536       5      0  2018      2780               56   8.40
#
#             votes  director  writer  star  country     budget       gross  \
# 5445 1,100,000.00      1155    1778  2334       55  237000000  2847246203
# 7445   903,000.00       162     743  2241       55  356000000  2797501328
# 3045 1,100,000.00      1155    1778  1595       55  200000000  2201647264
# 6663   876,000.00      1125    2550   524       55  245000000  2069521700
# 7244   897,000.00       162     743  2241       55  321000000  2048359754
#
#       company  runtime  yearcorrect
# 5445     2253   162.00           30
# 7445     1606   181.00           40
# 3045     2253   194.00           18
# 6663     1540   138.00           36
# 7244     1606   149.00           39

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized.corr()
# Out:
#                  name  rating  genre  year  released  releasedcountry  score  \
# name             1.00   -0.01   0.02  0.01      0.01            -0.00   0.02
# rating          -0.01    1.00   0.07  0.01      0.00             0.02  -0.00
# genre            0.02    0.07   1.00 -0.08     -0.08            -0.09   0.03
# year             0.01    0.01  -0.08  1.00      1.00            -0.09   0.10
# released         0.01    0.00  -0.08  1.00      1.00            -0.09   0.11
# releasedcountry -0.00    0.02  -0.09 -0.09     -0.09             1.00  -0.09
# score            0.02   -0.00   0.03  0.10      0.11            -0.09   1.00
# votes            0.01    0.03  -0.15  0.22      0.22             0.09   0.41
# director         0.01    0.02  -0.02 -0.02     -0.02             0.01   0.01
# writer           0.01   -0.01   0.01 -0.01     -0.01            -0.00   0.02
# star             0.01    0.01  -0.01 -0.03     -0.03            -0.02  -0.00
# country         -0.01    0.08  -0.04 -0.07     -0.08             0.30  -0.13
# budget           0.02   -0.08  -0.33  0.31      0.30             0.17   0.06
# gross            0.01   -0.10  -0.23  0.26      0.26             0.12   0.19
# company          0.01   -0.03  -0.07 -0.01     -0.01             0.09   0.00
# runtime          0.01    0.06  -0.05  0.12      0.12            -0.01   0.40
# yearcorrect      0.01    0.01  -0.08  1.00      1.00            -0.09   0.11
#
#                  votes  director  writer  star  country  budget  gross  \
# name              0.01      0.01    0.01  0.01    -0.01    0.02   0.01
# rating            0.03      0.02   -0.01  0.01     0.08   -0.08  -0.10
# genre            -0.15     -0.02    0.01 -0.01    -0.04   -0.33  -0.23
# year              0.22     -0.02   -0.01 -0.03    -0.07    0.31   0.26
# released          0.22     -0.02   -0.01 -0.03    -0.08    0.30   0.26
# releasedcountry   0.09      0.01   -0.00 -0.02     0.30    0.17   0.12
# score             0.41      0.01    0.02 -0.00    -0.13    0.06   0.19
# votes             1.00      0.00    0.00 -0.02     0.07    0.49   0.63
# director          0.00      1.00    0.30  0.04     0.02    0.00  -0.01
# writer            0.00      0.30    1.00  0.03     0.02   -0.03  -0.02
# star             -0.02      0.04    0.03  1.00    -0.01   -0.02  -0.00
# country           0.07      0.02    0.02 -0.01     1.00    0.13   0.10
# budget            0.49      0.00   -0.03 -0.02     0.13    1.00   0.75
# gross             0.63     -0.01   -0.02 -0.00     0.10    0.75   1.00
# company           0.13      0.00    0.01  0.01     0.10    0.19   0.16
# runtime           0.31      0.02   -0.00  0.01    -0.08    0.27   0.25
# yearcorrect       0.22     -0.02   -0.01 -0.03    -0.08    0.30   0.26
#
#                  company  runtime  yearcorrect
# name                0.01     0.01         0.01
# rating             -0.03     0.06         0.01
# genre              -0.07    -0.05        -0.08
# year               -0.01     0.12         1.00
# released           -0.01     0.12         1.00
# releasedcountry     0.09    -0.01        -0.09
# score               0.00     0.40         0.11
# votes               0.13     0.31         0.22
# director            0.00     0.02        -0.02
# writer              0.01    -0.00        -0.01
# star                0.01     0.01        -0.03
# country             0.10    -0.08        -0.08
# budget              0.19     0.27         0.30
# gross               0.16     0.25         0.26
# company             1.00     0.03        -0.01
# runtime             0.03     1.00         0.12
# yearcorrect        -0.01     0.12         1.00

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name             name               1.00
#                  rating            -0.01
#                  genre              0.02
#                  year               0.01
#                  released           0.01
#                  releasedcountry   -0.00
#                  score              0.02
#                  votes              0.01
#                  director           0.01
#                  writer             0.01
#                  star               0.01
#                  country           -0.01
#                  budget             0.02
#                  gross              0.01
#                  company            0.01
#                  runtime            0.01
#                  yearcorrect        0.01
# rating           name              -0.01
#                  rating             1.00
#                  genre              0.07
#                  year               0.01
#                  released           0.00
#                  releasedcountry    0.02
#                  score             -0.00
#                  votes              0.03
#                  director           0.02
#                  writer            -0.01
#                  star               0.01
#                  country            0.08
#                  budget            -0.08
#                  gross             -0.10
#                  company           -0.03
#                  runtime            0.06
#                  yearcorrect        0.01
# genre            name               0.02
#                  rating             0.07
#                  genre              1.00
#                  year              -0.08
#                  released          -0.08
#                  releasedcountry   -0.09
#                  score              0.03
#                  votes             -0.15
#                  director          -0.02
#                  writer             0.01
#                  star              -0.01
#                  country           -0.04
#                  budget            -0.33
#                  gross             -0.23
#                  company           -0.07
#                  runtime           -0.05
#                  yearcorrect       -0.08
# year             name               0.01
#                  rating             0.01
#                  genre             -0.08
#                  year               1.00
#                  released           1.00
#                  releasedcountry   -0.09
#                  score              0.10
#                  votes              0.22
#                  director          -0.02
#                  writer            -0.01
#                  star              -0.03
#                  country           -0.07
#                  budget             0.31
#                  gross              0.26
#                  company           -0.01
#                  runtime            0.12
#                  yearcorrect        1.00
# released         name               0.01
#                  rating             0.00
#                  genre             -0.08
#                  year               1.00
#                  released           1.00
#                  releasedcountry   -0.09
#                  score              0.11
#                  votes              0.22
#                  director          -0.02
#                  writer            -0.01
#                  star              -0.03
#                  country           -0.08
#                  budget             0.30
#                  gross              0.26
#                  company           -0.01
#                  runtime            0.12
#                  yearcorrect        1.00
# releasedcountry  name              -0.00
#                  rating             0.02
#                  genre             -0.09
#                  year              -0.09
#                  released          -0.09
#                  releasedcountry    1.00
#                  score             -0.09
#                  votes              0.09
#                  director           0.01
#                  writer            -0.00
#                  star              -0.02
#                  country            0.30
#                  budget             0.17
#                  gross              0.12
#                  company            0.09
#                  runtime           -0.01
#                  yearcorrect       -0.09
# score            name               0.02
#                  rating            -0.00
#                  genre              0.03
#                  year               0.10
#                  released           0.11
#                  releasedcountry   -0.09
#                  score              1.00
#                  votes              0.41
#                  director           0.01
#                  writer             0.02
#                  star              -0.00
#                  country           -0.13
#                  budget             0.06
#                  gross              0.19
#                  company            0.00
#                  runtime            0.40
#                  yearcorrect        0.11
# votes            name               0.01
#                  rating             0.03
#                  genre             -0.15
#                  year               0.22
#                  released           0.22
#                  releasedcountry    0.09
#                  score              0.41
#                  votes              1.00
#                  director           0.00
#                  writer             0.00
#                  star              -0.02
#                  country            0.07
#                  budget             0.49
#                  gross              0.63
#                  company            0.13
#                  runtime            0.31
#                  yearcorrect        0.22
# director         name               0.01
#                  rating             0.02
#                  genre             -0.02
#                  year              -0.02
#                  released          -0.02
#                  releasedcountry    0.01
#                  score              0.01
#                  votes              0.00
#                  director           1.00
#                  writer             0.30
#                  star               0.04
#                  country            0.02
#                  budget             0.00
#                  gross             -0.01
#                  company            0.00
#                  runtime            0.02
#                  yearcorrect       -0.02
# writer           name               0.01
#                  rating            -0.01
#                  genre              0.01
#                  year              -0.01
#                  released          -0.01
#                  releasedcountry   -0.00
#                  score              0.02
#                  votes              0.00
#                  director           0.30
#                  writer             1.00
#                  star               0.03
#                  country            0.02
#                  budget            -0.03
#                  gross             -0.02
#                  company            0.01
#                  runtime           -0.00
#                  yearcorrect       -0.01
# star             name               0.01
#                  rating             0.01
#                  genre             -0.01
#                  year              -0.03
#                  released          -0.03
#                  releasedcountry   -0.02
#                  score             -0.00
#                  votes             -0.02
#                  director           0.04
#                  writer             0.03
#                  star               1.00
#                  country           -0.01
#                  budget            -0.02
#                  gross             -0.00
#                  company            0.01
#                  runtime            0.01
#                  yearcorrect       -0.03
# country          name              -0.01
#                  rating             0.08
#                  genre             -0.04
#                  year              -0.07
#                  released          -0.08
#                  releasedcountry    0.30
#                  score             -0.13
#                  votes              0.07
#                  director           0.02
#                  writer             0.02
#                  star              -0.01
#                  country            1.00
#                  budget             0.13
#                  gross              0.10
#                  company            0.10
#                  runtime           -0.08
#                  yearcorrect       -0.08
# budget           name               0.02
#                  rating            -0.08
#                  genre             -0.33
#                  year               0.31
#                  released           0.30
#                  releasedcountry    0.17
#                  score              0.06
#                  votes              0.49
#                  director           0.00
#                  writer            -0.03
#                  star              -0.02
#                  country            0.13
#                  budget             1.00
#                  gross              0.75
#                  company            0.19
#                  runtime            0.27
#                  yearcorrect        0.30
# gross            name               0.01
#                  rating            -0.10
#                  genre             -0.23
#                  year               0.26
#                  released           0.26
#                  releasedcountry    0.12
#                  score              0.19
#                  votes              0.63
#                  director          -0.01
#                  writer            -0.02
#                  star              -0.00
#                  country            0.10
#                  budget             0.75
#                  gross              1.00
#                  company            0.16
#                  runtime            0.25
#                  yearcorrect        0.26
# company          name               0.01
#                  rating            -0.03
#                  genre             -0.07
#                  year              -0.01
#                  released          -0.01
#                  releasedcountry    0.09
#                  score              0.00
#                  votes              0.13
#                  director           0.00
#                  writer             0.01
#                  star               0.01
#                  country            0.10
#                  budget             0.19
#                  gross              0.16
#                  company            1.00
#                  runtime            0.03
#                  yearcorrect       -0.01
# runtime          name               0.01
#                  rating             0.06
#                  genre             -0.05
#                  year               0.12
#                  released           0.12
#                  releasedcountry   -0.01
#                  score              0.40
#                  votes              0.31
#                  director           0.02
#                  writer            -0.00
#                  star               0.01
#                  country           -0.08
#                  budget             0.27
#                  gross              0.25
#                  company            0.03
#                  runtime            1.00
#                  yearcorrect        0.12
# yearcorrect      name               0.01
#                  rating             0.01
#                  genre             -0.08
#                  year               1.00
#                  released           1.00
#                  releasedcountry   -0.09
#                  score              0.11
#                  votes              0.22
#                  director          -0.02
#                  writer            -0.01
#                  star              -0.03
#                  country           -0.08
#                  budget             0.30
#                  gross              0.26
#                  company           -0.01
#                  runtime            0.12
#                  yearcorrect        1.00
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget           genre             -0.33
# genre            budget            -0.33
#                  gross             -0.23
# gross            genre             -0.23
# genre            votes             -0.15
# votes            genre             -0.15
# country          score             -0.13
# score            country           -0.13
# rating           gross             -0.10
# gross            rating            -0.10
# score            releasedcountry   -0.09
# releasedcountry  score             -0.09
# yearcorrect      releasedcountry   -0.09
# releasedcountry  yearcorrect       -0.09
#                  genre             -0.09
# genre            releasedcountry   -0.09
# releasedcountry  year              -0.09
# year             releasedcountry   -0.09
# releasedcountry  released          -0.09
# released         releasedcountry   -0.09
# country          yearcorrect       -0.08
# yearcorrect      country           -0.08
# budget           rating            -0.08
# rating           budget            -0.08
# genre            year              -0.08
# year             genre             -0.08
# country          released          -0.08
# released         country           -0.08
# yearcorrect      genre             -0.08
# genre            yearcorrect       -0.08
# released         genre             -0.08
# genre            released          -0.08
# runtime          country           -0.08
# country          runtime           -0.08
# company          genre             -0.07
# genre            company           -0.07
# year             country           -0.07
# country          year              -0.07
# runtime          genre             -0.05
# genre            runtime           -0.05
#                  country           -0.04
# country          genre             -0.04
# company          rating            -0.03
# rating           company           -0.03
# year             star              -0.03
# star             year              -0.03
# yearcorrect      star              -0.03
# star             yearcorrect       -0.03
#                  released          -0.03
# released         star              -0.03
# budget           writer            -0.03
# writer           budget            -0.03
# releasedcountry  star              -0.02
# star             releasedcountry   -0.02
# writer           gross             -0.02
# gross            writer            -0.02
# year             director          -0.02
# director         year              -0.02
#                  released          -0.02
# released         director          -0.02
# budget           star              -0.02
# star             budget            -0.02
#                  votes             -0.02
# votes            star              -0.02
# yearcorrect      director          -0.02
# director         yearcorrect       -0.02
#                  genre             -0.02
# genre            director          -0.02
# director         gross             -0.01
# gross            director          -0.01
# company          yearcorrect       -0.01
# yearcorrect      company           -0.01
# company          released          -0.01
# released         company           -0.01
# country          star              -0.01
# star             country           -0.01
# releasedcountry  runtime           -0.01
# runtime          releasedcountry   -0.01
# name             country           -0.01
# country          name              -0.01
# company          year              -0.01
# year             company           -0.01
# writer           year              -0.01
# year             writer            -0.01
# rating           name              -0.01
# name             rating            -0.01
# released         writer            -0.01
# writer           released          -0.01
# yearcorrect      writer            -0.01
# writer           yearcorrect       -0.01
# rating           writer            -0.01
# writer           rating            -0.01
# genre            star              -0.01
# star             genre             -0.01
# runtime          writer            -0.00
# writer           runtime           -0.00
# releasedcountry  name              -0.00
# name             releasedcountry   -0.00
# score            star              -0.00
# star             score             -0.00
# score            rating            -0.00
# rating           score             -0.00
# releasedcountry  writer            -0.00
# writer           releasedcountry   -0.00
# gross            star              -0.00
# star             gross             -0.00
# votes            director           0.00
# director         votes              0.00
# votes            writer             0.00
# writer           votes              0.00
# score            company            0.00
# company          score              0.00
# rating           released           0.00
# released         rating             0.00
# director         company            0.00
# company          director           0.00
# director         budget             0.00
# budget           director           0.00
# company          writer             0.01
# writer           company            0.01
# rating           yearcorrect        0.01
# yearcorrect      rating             0.01
# star             name               0.01
# name             star               0.01
# genre            writer             0.01
# writer           genre              0.01
# gross            name               0.01
# name             gross              0.01
# year             rating             0.01
# rating           year               0.01
# name             director           0.01
# director         name               0.01
# writer           name               0.01
# name             writer             0.01
# company          name               0.01
# name             company            0.01
# score            director           0.01
# director         score              0.01
# star             runtime            0.01
# runtime          star               0.01
# name             runtime            0.01
# runtime          name               0.01
# name             released           0.01
# released         name               0.01
# yearcorrect      name               0.01
# name             yearcorrect        0.01
# year             name               0.01
# name             year               0.01
# company          star               0.01
# star             company            0.01
# name             votes              0.01
# votes            name               0.01
# releasedcountry  director           0.01
# director         releasedcountry    0.01
# star             rating             0.01
# rating           star               0.01
# writer           country            0.02
# country          writer             0.02
# name             genre              0.02
# genre            name               0.02
# name             score              0.02
# score            name               0.02
# country          director           0.02
# director         country            0.02
# runtime          director           0.02
# director         runtime            0.02
# writer           score              0.02
# score            writer             0.02
# director         rating             0.02
# rating           director           0.02
# name             budget             0.02
# budget           name               0.02
# releasedcountry  rating             0.02
# rating           releasedcountry    0.02
# star             writer             0.03
# writer           star               0.03
# score            genre              0.03
# genre            score              0.03
# rating           votes              0.03
# votes            rating             0.03
# company          runtime            0.03
# runtime          company            0.03
# director         star               0.04
# star             director           0.04
# score            budget             0.06
# budget           score              0.06
# runtime          rating             0.06
# rating           runtime            0.06
# genre            rating             0.07
# rating           genre              0.07
# votes            country            0.07
# country          votes              0.07
#                  rating             0.08
# rating           country            0.08
# votes            releasedcountry    0.09
# releasedcountry  votes              0.09
#                  company            0.09
# company          releasedcountry    0.09
# gross            country            0.10
# country          gross              0.10
#                  company            0.10
# company          country            0.10
# score            year               0.10
# year             score              0.10
# yearcorrect      score              0.11
# score            yearcorrect        0.11
# released         score              0.11
# score            released           0.11
# gross            releasedcountry    0.12
# releasedcountry  gross              0.12
# yearcorrect      runtime            0.12
# runtime          yearcorrect        0.12
#                  year               0.12
# year             runtime            0.12
# released         runtime            0.12
# runtime          released           0.12
# budget           country            0.13
# country          budget             0.13
# votes            company            0.13
# company          votes              0.13
# gross            company            0.16
# company          gross              0.16
# budget           releasedcountry    0.17
# releasedcountry  budget             0.17
# gross            score              0.19
# score            gross              0.19
# budget           company            0.19
# company          budget             0.19
# votes            released           0.22
# released         votes              0.22
# votes            yearcorrect        0.22
# yearcorrect      votes              0.22
# year             votes              0.22
# votes            year               0.22
# runtime          gross              0.25
# gross            runtime            0.25
#                  yearcorrect        0.26
# yearcorrect      gross              0.26
# released         gross              0.26
# gross            released           0.26
# year             gross              0.26
# gross            year               0.26
# runtime          budget             0.27
# budget           runtime            0.27
# releasedcountry  country            0.30
# country          releasedcountry    0.30
# writer           director           0.30
# director         writer             0.30
# budget           yearcorrect        0.30
# yearcorrect      budget             0.30
# budget           released           0.30
# released         budget             0.30
# year             budget             0.31
# budget           year               0.31
# votes            runtime            0.31
# runtime          votes              0.31
#                  score              0.40
# score            runtime            0.40
# votes            score              0.41
# score            votes              0.41
# votes            budget             0.49
# budget           votes              0.49
# gross            votes              0.63
# votes            gross              0.63
# gross            budget             0.75
# budget           gross              0.75
# released         year               1.00
# year             released           1.00
# yearcorrect      year               1.00
# year             yearcorrect        1.00
# yearcorrect      released           1.00
# released         yearcorrect        1.00
# name             name               1.00
# director         director           1.00
# company          company            1.00
# gross            gross              1.00
# budget           budget             1.00
# country          country            1.00
# star             star               1.00
# writer           writer             1.00
# votes            votes              1.00
# score            score              1.00
# releasedcountry  releasedcountry    1.00
# released         released           1.00
# year             year               1.00
# genre            genre              1.00
# rating           rating             1.00
# runtime          runtime            1.00
# yearcorrect      yearcorrect        1.00
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross            votes             0.63
# votes            gross             0.63
# gross            budget            0.75
# budget           gross             0.75
# released         year              1.00
# year             released          1.00
# yearcorrect      year              1.00
# year             yearcorrect       1.00
# yearcorrect      released          1.00
# released         yearcorrect       1.00
# name             name              1.00
# director         director          1.00
# company          company           1.00
# gross            gross             1.00
# budget           budget            1.00
# country          country           1.00
# star             star              1.00
# writer           writer            1.00
# votes            votes             1.00
# score            score             1.00
# releasedcountry  releasedcountry   1.00
# released         released          1.00
# year             year              1.00
# genre            genre             1.00
# rating           rating            1.00
# runtime          runtime           1.00
# yearcorrect      yearcorrect       1.00
# dtype: float64
